# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('./crowling/merged_crowling_ver_2.csv', encoding='utf-8')
df.head(3)
# Out:
#           질환명                                                동의어  \
# 0  과민성 대장 증후군  ['과민성대장', '과민성대장증후군', '과민성장증후군', '과민성창자', '과민성...
# 1         당뇨병                                             ['당뇨']
# 2         심부전           ['울혈성심부전', '울혈성심부전증', '울혈심부전', '울혈심부전증']
#
#                                               증상 키워드  \
# 0  ['변비', '두통', '복부팽만감', '설사', '점액변', '복통', '체중감소...
# 1  ['무감각증', '변비', '소양감', '단백뇨', '다음', '고혈당', '피로감...
# 2  ['두통', '빈맥', '기침', '소변량감소', '피로감', '부종', '청색증'...
#
#                                             증상 등장 빈도  \
# 0  [{'두통': 1, '복통': 2, '위경련': 1, '복부팽만감': 1, '변비'...
# 1  [{'무감각증': 1, '소양감': 2, '변비': 1, '저혈압': 1, '거품뇨...
# 2  [{'기침': 1, '피로감': 1, '호흡곤란': 2, '부종': 1, '빈맥':...
#
#                                                  증상1  \
# 0  전형적인 증상으로는 복통과 배변 습관의 변화를 들 수 있는데 복통이 심하더라도 배변...
# 1  약한 고혈당에서는 대부분의 환자들이 증상을 느끼지 못하거나 모호해서 당뇨병이라고 생...
# 2  가장 흔하고 중요한 증상은 숨이 차는 것(호흡곤란)이다. 계단을 오르기만 해도 과도...
#
#                                                  증상2  \
# 0  대장은 정상적으로 하루 1회 정도 배변을 유도하도록 움직입니다. 그러나 대장이 과민...
# 1  당뇨병에 걸리면 소변으로 포도당이 빠져나가는데, 이때 수분을 같이 끌고 나가기 때문...
# 2  울혈성 심부전의 일반적인 증상으로는 전반적으로 몸이 약해짐, 피곤함, 운동을 조금만...
#
#                                                  치료1  \
# 0  치료는 과민성 대장 증후군의 원인이 되는 심리적 불안과 갈등을 제거하는 것이 가장 ...
# 1  제1형 당뇨병의 경우에는 인슐린 치료가 필요하다. 제2형 당뇨병의 경우에는 생활 습...
# 2  급성이냐 만성이냐에 따라 치료 방침은 다르다. 급성 심부전은 주로 1주일 이내 갑자...
#
#                                                  치료2  \
# 0  자극성 장 증후군의 원인이 되는 심리적 불안과 갈등을 제거하는 것이 가장 중요합니다...
# 1  당뇨병의 치료 방법으로는 식사 요법, 운동 요법, 약물 치료가 있습니다. 가벼운 당...
# 2  1. 약물 요법\n  1) 일반적인 원칙\n약물 요법은 이뇨제, 안지오텐신 계열 차...
#
#                                                  경과1  \
# 0  이 질환은 암이나 환자의 인격 이상과도 무관하며 감별을 요하는 다른 질환(궤양성 대...
# 1  갑자기 몸 안에서 인슐린이 부족하게 되면 급성 합병증이 생길 수 있다. 급성 합병증...
# 2  심부전의 이환율과 유병율은 계속 증가하고 있는데, 이는 인구가 노령화되고 의학적 지...
#
#                                                  경과2  \
# 0  암이나 환자의 정신과적인 이상 소견(인격 이상 등)과 관련이 있습니다. 감별이 필요...
# 1  당뇨병의 합병증에는 급성 대사성 합병증과 만성 합병증이 있습니다. 급성 대사성 합병...
# 2  울혈성 심부전은 여성보다 남성에게 더 흔하게 나타납니다. 사망률은 심부전의 발생 원...
#
#                                                생활가이드  \
# 0  과민성 대장 증후군 환자는 스트레스를 줄이는 것이 급선무입니다. 먼저 자신의 주요 ...
# 1  자신이 느끼는 증상만으로 혈당을 조절하는 것은 위험하며, 반드시 자가 혈당 측정기를...
# 2  규칙적 운동이 필요하지만 지나치게 격렬한 운동은 제한하는 것이 좋습니다. 술과 담배...
#
#                                                 주의사항  \
# 0  저지방식, 저자극식을 원칙으로 식사합니다. 지방성 음식, 향신료가 많이 들어간 음식...
# 1  당뇨병을 예방하기 위해서는 일단 당뇨병을 유발할 수 있는 환경 인자인 비만, 좌식 ...
# 2  디지탈리스의 혈중 치료 농도는 일반적으로 1~2mcg/mL입니다. 일반적으로 2mc...
#
#                                                 예방방법 FAQ  \
# 0                                                  .   .
# 1  생활습관 교정을 통해서 체중을 5~7% 줄이게 되면 일부는 제2형 당뇨병의 발병을 ...   .
# 2  과도한 음주, 과도한 스트레스, 지속적인 빠른 맥박수는 이 자체가 심부전을 초래할 ...   .
#
#                                                 URL1  \
# 0  http://www.snuh.org/health/nMedInfo/nView.do?c...
# 1  http://www.snuh.org/health/nMedInfo/nView.do?c...
# 2  http://www.snuh.org/health/nMedInfo/nView.do?c...
#
#                                                 URL2
# 0  https://www.amc.seoul.kr/asan/healthinfo/disea...
# 1  https://www.amc.seoul.kr/asan/healthinfo/disea...
# 2  https://www.amc.seoul.kr/asan/healthinfo/disea...

# %%
df[["질환명", "증상 키워드"]]
# Out:
#            질환명                                             증상 키워드
# 0   과민성 대장 증후군            [변비, 두통, 복부팽만감, 설사, 점액변, 복통, 체중감소, 위경련]
# 1          당뇨병  [무감각증, 변비, 소양감, 단백뇨, 다음, 고혈당, 피로감, 다뇨, 저혈압, 시야...
# 2          심부전  [두통, 빈맥, 기침, 소변량감소, 피로감, 부종, 청색증, 불면증, 심부전, 호흡...
# 3           천식                    [만성기침, 기침, 가래, 호흡곤란, 가슴통증, 천명음]
# 4       급성 대장염              [구토, 설사, 혈변, 배변습관의변화, 복통, 구역, 열, 점액변]
# 5           감기      [근육통, 두통, 재채기, 기침, 피로감, 비루, 열, 콧물, 목의통증, 코막힘]
# 6    급성 경막하 출혈                       [두통, 구토, 반신마비, 호흡곤란, 구역, 혼수]
# 7        인플루엔자                 [근육통, 두통, 구토, 기침, 설사, 목의통증, 오한, 열]
# 8       긴장성 두통                                           [압통, 두통]
# 9          고산병  [두통, 마비, 구토, 기침, 의식장애, 청색증, 탈수, 수면장애, 말초부종, 식욕...
# 10      아나필락시스  [소양감, 실신, 구토, 빈맥, 의식장애, 천명, 부종, 기침, 발진, 어지럼증, ...
# 11        루게릭병  [발감각저하, 근력약화, 실행증, 피부긴장도저하, 저혈압, 언어장애, 호흡곤란, 삼...
# 12         장폐색  [변비, 구토, 빈맥, 탈수, 설사, 장폐색, 복부팽만감, 저혈압, 복통, 구역, ...
# 13     아토피 피부염   [소양감, 환부의분비물, 피부소양감, 피부건조, 발진, 태선화, 물집, 습진, 작열감]
# 14        대상포진           [딱지, 환부통증, 두통, 소수포, 농포, 홍반, 발진, 수포, 작열감]
# 15      돌발성 난청                             [이명, 어지럼증, 귀의통증, 청력장애]
# 16       만성 비염    [재채기, 기침, 콧물, 비루, 후각장애, 목의통증, 폐쇄성비음, 후각소실, 코막힘]
# 17     급성 신우신염  [근육통, 두통, 구토, 배뇨통, 배뇨곤란, 빈뇨, 오심, 혈뇨, 잔뇨감, 오한, ...
# 18         뇌전증  [온몸이떨림, 의식장애, 청색증, 경련, 아린감, 눈꺼풀의떨림, 뇌전증발작, 떨림,...
# 19         패혈증  [근육통, 구토, 빈맥, 의식장애, 소변량감소, 반점, 빈호흡, 저혈압, 심부전, ...

# %%
for i in range(len(df)):
    df.at[i, '증상 키워드'] = df['증상 키워드'][i].replace("[", "").replace("]", "").replace(" ", "").replace("'", "").split(',')

symptoms = list(df["증상 키워드"])
symptoms[:3]
# Out:
# [['변비', '두통', '복부팽만감', '설사', '점액변', '복통', '체중감소', '위경련'],
#  ['무감각증',
#   '변비',
#   '소양감',
#   '단백뇨',
#   '다음',
#   '고혈당',
#   '피로감',
#   '다뇨',
#   '저혈압',
#   '시야장애',
#   '다식',
#   '체중감소',
#   '저림',
#   '거품뇨'],
#  ['두통',
#   '빈맥',
#   '기침',
#   '소변량감소',
#   '피로감',
#   '부종',
#   '청색증',
#   '불면증',
#   '심부전',
#   '호흡곤란',
#   '야뇨증',
#   '울혈성심부전']]

# %%
trns_en = TransactionEncoder()
symptoms_te = trns_en.fit(symptoms).transform(symptoms)

trns_df = pd.DataFrame(symptoms_te, columns=trns_en.columns_)
trns_df
# Out:
#        가래   가슴통증    거품뇨     경련    고혈당     구역     구토   귀의통증   근력약화  근육간대경련  \
# 0   False  False  False  False  False  False  False  False  False   False
# 1   False  False   True  False   True  False  False  False  False   False
# 2   False  False  False  False  False  False  False  False  False   False
# 3    True   True  False  False  False  False  False  False  False   False
# 4   False  False  False  False  False   True   True  False  False   False
# 5   False  False  False  False  False  False  False  False  False   False
# 6   False  False  False  False  False   True   True  False  False   False
# 7   False  False  False  False  False  False   True  False  False   False
# 8   False  False  False  False  False  False  False  False  False   False
# 9   False  False  False  False  False   True   True  False  False   False
# 10  False   True  False  False  False   True   True  False  False   False
# 11  False  False  False  False  False  False  False  False   True    True
# 12  False  False  False  False  False   True   True  False  False   False
# 13  False  False  False  False  False  False  False  False  False   False
# 14  False  False  False  False  False  False  False  False  False   False
# 15  False  False  False  False  False  False  False   True  False   False
# 16  False  False  False  False  False  False  False  False  False   False
# 17  False  False   True  False  False  False   True  False  False   False
# 18  False  False  False   True  False  False  False  False  False    True
# 19  False  False  False  False  False   True   True  False  False   False
#
#     ...  피부소양감     혈뇨     혈변   호흡곤란     혼수     홍반  환부의분비물   환부통증   후각소실   후각장애
# 0   ...  False  False  False  False  False  False   False  False  False  False
# 1   ...  False  False  False  False  False  False   False  False  False  False
# 2   ...  False  False  False   True  False  False   False  False  False  False
# 3   ...  False  False  False   True  False  False   False  False  False  False
# 4   ...  False  False   True  False  False  False   False  False  False  False
# 5   ...  False  False  False  False  False  False   False  False  False  False
# 6   ...  False  False  False   True   True  False   False  False  False  False
# 7   ...  False  False  False  False  False  False   False  False  False  False
# 8   ...  False  False  False  False  False  False   False  False  False  False
# 9   ...  False  False  False   True   True  False   False  False  False  False
# 10  ...   True  False  False   True  False  False   False  False  False  False
# 11  ...  False  False  False   True  False  False   False  False  False  False
# 12  ...  False  False  False  False  False  False   False  False  False  False
# 13  ...   True  False  False  False  False  False    True  False  False  False
# 14  ...  False  False  False  False  False   True   False   True  False  False
# 15  ...  False  False  False  False  False  False   False  False  False  False
# 16  ...  False  False  False  False  False  False   False  False   True   True
# 17  ...  False   True  False  False  False  False   False  False  False  False
# 18  ...  False  False  False  False   True  False   False  False  False  False
# 19  ...  False  False  False  False  False  False   False  False  False  False
#
# [20 rows x 107 columns]

# %%
symptoms_sets = apriori(trns_df, min_support=0.1, use_colnames=True, max_len=15)
symptoms_sets.sort_values(['support'], ascending=False)
# Out:
#      support                      itemsets
# 7       0.45                          (두통)
# 3       0.40                          (구토)
# 6       0.35                          (기침)
# 2       0.30                          (구역)
# 37      0.30                        (호흡곤란)
# ..       ...                           ...
# 144     0.10                   (저혈압, 호흡곤란)
# 143     0.10                     (저혈압, 저림)
# 142     0.10                     (콧물, 재채기)
# 141     0.10                    (코막힘, 재채기)
# 345     0.10  (코막힘, 재채기, 비루, 목의통증, 콧물, 기침)
#
# [346 rows x 2 columns]

# %%
rules = association_rules(symptoms_sets, metric="confidence", min_threshold=0.5)
# rules.to_csv('./crowling/rules.csv', index=False)
rules.sort_values(['confidence'], ascending=False)
# Out:
#           antecedents     consequents  antecedent support  consequent support  \
# 0              (가슴통증)            (기침)                 0.1                0.35
# 1304    (콧물, 비루, 재채기)          (목의통증)                 0.1                0.15
# 1316   (목의통증, 콧물, 비루)           (코막힘)                 0.1                0.10
# 1315  (목의통증, 콧물, 코막힘)            (비루)                 0.1                0.10
# 1314            (재채기)  (목의통증, 콧물, 비루)                 0.1                0.10
# ...               ...             ...                 ...                 ...
# 257            (의식장애)       (구역, 저혈압)                 0.2                0.15
# 261            (의식장애)      (구역, 호흡곤란)                 0.2                0.15
# 707            (의식장애)    (구토, 구역, 기침)                 0.2                0.10
# 267          (두통, 구토)           (근육통)                 0.2                0.20
# 876            (의식장애)  (구역, 기침, 호흡곤란)                 0.2                0.10
#
#       support  confidence       lift  leverage  conviction  zhangs_metric
# 0         0.1         1.0   2.857143     0.065         inf       0.722222
# 1304      0.1         1.0   6.666667     0.085         inf       0.944444
# 1316      0.1         1.0  10.000000     0.090         inf       1.000000
# 1315      0.1         1.0  10.000000     0.090         inf       1.000000
# 1314      0.1         1.0  10.000000     0.090         inf       1.000000
# ...       ...         ...        ...       ...         ...            ...
# 257       0.1         0.5   3.333333     0.070         1.7       0.875000
# 261       0.1         0.5   3.333333     0.070         1.7       0.875000
# 707       0.1         0.5   5.000000     0.080         1.8       1.000000
# 267       0.1         0.5   2.500000     0.060         1.6       0.750000
# 876       0.1         0.5   5.000000     0.080         1.8       1.000000
#
# [2037 rows x 10 columns]

# %% [markdown]
# ---

# %%
user_symptoms = input("증상을 입력하세요: ").replace(" ", "").split(",")
user_symptoms
# Out:
# ['두통', '구토', '혈뇨']

# %%
import itertools

all_subsets = []
for i in range(len(user_symptoms)):
    all_subsets.extend(list(list(itertools.combinations(user_symptoms, i+1))))
all_subsets
# Out:
# [('두통',),
#  ('구토',),
#  ('혈뇨',),
#  ('두통', '구토'),
#  ('두통', '혈뇨'),
#  ('구토', '혈뇨'),
#  ('두통', '구토', '혈뇨')]

# %%
keyword_combi = pd.DataFrame(columns=["keyword", "support"])

for i in range(len(symptoms_sets)):
    for subset in all_subsets:
        if set(subset) == (set(symptoms_sets['itemsets'][i])):
            keyword_combi.loc[len(keyword_combi)] = \
                [list(symptoms_sets['itemsets'][i]), symptoms_sets['support'][i]]
keyword_combi.sort_values(['support'], ascending=False)
# Out:
#     keyword  support
# 1      [두통]     0.45
# 0      [구토]     0.40
# 2  [두통, 구토]     0.20

# %%
user_syt_df = pd.DataFrame(columns=rules.columns)
for i in range(len(keyword_combi)):        
    filtered = rules[rules["antecedents"] == frozenset(keyword_combi["keyword"][i])]
    filtered.sort_values(['support'], ascending=False)
    user_syt_df = pd.concat([user_syt_df, filtered])
user_syt_df.sort_values(['confidence'], ascending=False)
# Out:
# C:\Users\chaewon\AppData\Local\Temp\ipykernel_19416\2032524936.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   user_syt_df = pd.concat([user_syt_df, filtered])
#      antecedents     consequents  antecedent support  consequent support  \
# 2           (구토)            (구역)                 0.4                0.30
# 19          (구토)            (두통)                 0.4                0.45
# 1525    (구토, 두통)  (구역, 호흡곤란, 혼수)                 0.2                0.10
# 1009    (두통, 구토)      (호흡곤란, 혼수)                 0.2                0.10
# 1000    (두통, 구토)         (열, 오한)                 0.2                0.15
# 941     (두통, 구토)       (오한, 근육통)                 0.2                0.15
# 930     (두통, 구토)        (열, 근육통)                 0.2                0.20
# 732     (두통, 구토)        (구역, 혼수)                 0.2                0.10
# 723     (두통, 구토)      (구역, 호흡곤란)                 0.2                0.15
# 305     (두통, 구토)            (혼수)                 0.2                0.15
# 302     (두통, 구토)          (호흡곤란)                 0.2                0.30
# 298     (두통, 구토)            (오한)                 0.2                0.15
# 295     (두통, 구토)             (열)                 0.2                0.25
# 281     (두통, 구토)            (기침)                 0.2                0.35
# 267     (두통, 구토)           (근육통)                 0.2                0.20
# 162     (두통, 구토)            (구역)                 0.2                0.30
# 24          (구토)             (열)                 0.4                0.25
# 1649    (구토, 두통)    (오한, 근육통, 열)                 0.2                0.15
#
#       support  confidence      lift  leverage  conviction  zhangs_metric
# 2         0.3        0.75  2.500000      0.18         2.8       1.000000
# 19        0.2        0.50  1.111111      0.02         1.1       0.166667
# 1525      0.1        0.50  5.000000      0.08         1.8       1.000000
# 1009      0.1        0.50  5.000000      0.08         1.8       1.000000
# 1000      0.1        0.50  3.333333      0.07         1.7       0.875000
# 941       0.1        0.50  3.333333      0.07         1.7       0.875000
# 930       0.1        0.50  2.500000      0.06         1.6       0.750000
# 732       0.1        0.50  5.000000      0.08         1.8       1.000000
# 723       0.1        0.50  3.333333      0.07         1.7       0.875000
# 305       0.1        0.50  3.333333      0.07         1.7       0.875000
# 302       0.1        0.50  1.666667      0.04         1.4       0.500000
# 298       0.1        0.50  3.333333      0.07         1.7       0.875000
# 295       0.1        0.50  2.000000      0.05         1.5       0.625000
# 281       0.1        0.50  1.428571      0.03         1.3       0.375000
# 267       0.1        0.50  2.500000      0.06         1.6       0.750000
# 162       0.1        0.50  1.666667      0.04         1.4       0.500000
# 24        0.2        0.50  2.000000      0.10         1.5       0.833333
# 1649      0.1        0.50  3.333333      0.07         1.7       0.875000

# %%
item_sets = []
for i in range(len(user_syt_df)):
    item_sets.append(list(user_syt_df['antecedents'].values[i]) + list(user_syt_df['consequents'].values[i]))
item_sets
# Out:
# [['구토', '구역'],
#  ['구토', '두통'],
#  ['구토', '열'],
#  ['두통', '구토', '구역'],
#  ['두통', '구토', '근육통'],
#  ['두통', '구토', '기침'],
#  ['두통', '구토', '열'],
#  ['두통', '구토', '오한'],
#  ['두통', '구토', '호흡곤란'],
#  ['두통', '구토', '혼수'],
#  ['두통', '구토', '구역', '호흡곤란'],
#  ['두통', '구토', '구역', '혼수'],
#  ['두통', '구토', '열', '근육통'],
#  ['두통', '구토', '오한', '근육통'],
#  ['두통', '구토', '열', '오한'],
#  ['두통', '구토', '호흡곤란', '혼수'],
#  ['구토', '두통', '구역', '호흡곤란', '혼수'],
#  ['구토', '두통', '오한', '근육통', '열']]

# %%
# def match_score(disease):
#     import numpy as np
#     score = 0
#     for i in range(len(df)):
#         if df["질환명"][i] == disease:
#             length = np.log(len(df["증상 키워드"][i]))
#             for symptom in user_symptoms:
#                 if symptom in df["증상 키워드"][i]:
#                     score += 1
#                 else:
#                     length += 1

#     score = (score / length) * 50
    
#     return score

def match_score(disease):
    import numpy as np
    score = 0
    for i in range(len(df)):
        if df["질환명"][i] == disease:
            length = len(df["증상 키워드"][i])
            
            if set(user_symptoms).issubset(set(df["증상 키워드"][i])):
                score += (len(user_symptoms))
                
            for symptom in user_symptoms:
                
                if symptom in df["증상 키워드"][i]:
                    score += 1
                else:
                    length += 1

    score = (score / length) * 100
    return score

# %%
best_matches = {}
able_diseases = {}
able_df_disases = {}

for i in range(len(df["증상 키워드"])):
    if set(user_symptoms) == set(df["증상 키워드"][i]):
        best_matches[df["질환명"][i]] = match_score(df["질환명"][i])
    else:
        if len(item_sets) != 0:        
            for item_set in item_sets:
                if set(item_set).issubset(set(df["증상 키워드"][i])):
                    able_diseases[df["질환명"][i]] = match_score(df["질환명"][i])
        else:
            if set(user_symptoms).issubset(set(df["증상 키워드"][i])):
                able_df_disases[df["질환명"][i]] = match_score(df["질환명"][i])

# %%
results = {}

if len(best_matches) != 0:
    scores = sorted(list(best_matches.values()), reverse=True)
    for score in scores:
        best = list(best_matches.keys())[list(best_matches.values()).index(score)]
        print(f"입력하신 증상에 대해 가장 적합한 질환은 {best}이며, 일치도는 {score:.2f}% 입니다.")
        results[best] = score
        
if len(able_diseases) != 0:
    scores = sorted(list(able_diseases.values()), reverse=True)
    for score in scores:
        able = list(able_diseases.keys())[list(able_diseases.values()).index(score)]
        print(f"ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 {able}이며, 일치도는 {score:.2f}% 입니다.")
        results[able] = score
        
if len(able_df_disases) != 0:
    scores = sorted(list(able_df_disases.values()), reverse=True)
    for score in scores:
        able_df = list(able_df_disases.keys())[list(able_df_disases.values()).index(score)]
        print(f"Dataframe 내 탐색 기반 입력하신 증상에 대해 가능성 있는 질환은 {able_df}, 일치도는 {score:.2f}% 입니다.")
        results[able_df] = score
# Out:
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 급성 신우신염이며, 일치도는 46.15% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 급성 경막하 출혈이며, 일치도는 28.57% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 인플루엔자이며, 일치도는 22.22% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 고산병이며, 일치도는 13.33% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 급성 대장염이며, 일치도는 10.00% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 장폐색이며, 일치도는 7.69% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 패혈증이며, 일치도는 5.88% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 아나필락시스이며, 일치도는 5.00% 입니다.

# %%
sorted_results = []
if len(results) != 0:
    scores = sorted(list(results.values()), reverse=True)
    for score in scores:
        sorted_results.append(list(results.keys())[list(results.values()).index(score)])
print(sorted_results)
# Out:
# ['급성 신우신염', '급성 경막하 출혈', '인플루엔자', '고산병', '급성 대장염', '장폐색', '패혈증', '아나필락시스']

# %%
print(f"입력하신 증상은 {user_symptoms} 입니다.")
print("===================================================================")
for i in range(3):
    if i < len(sorted_results):
        print(f"{i+1}순위 질환은 {sorted_results[i]}입니다.")
        print(f"{sorted_results[i]}의 증상은 {df[df['질환명'] == sorted_results[i]]['증상 키워드'].values[0]} 입니다.")
        print(f"증상 일치도는 {results[sorted_results[i]]:.2f}% 입니다.")
        print(f"자세한 정보는 아래 링크에서 확인하실 수 있습니다.")
        print(df[df['질환명'] == sorted_results[i]]['URL1'].values[0])
        print(df[df['질환명'] == sorted_results[i]]['URL2'].values[0])
        print("===================================================================")
    else:
        break
# Out:
# 입력하신 증상은 ['두통', '구토', '혈뇨'] 입니다.
# ===================================================================
# 1순위 질환은 급성 신우신염입니다.
# 급성 신우신염의 증상은 ['근육통', '두통', '구토', '배뇨통', '배뇨곤란', '빈뇨', '오심', '혈뇨', '잔뇨감', '오한', '열', '거품뇨', '요통'] 입니다.
# 증상 일치도는 46.15% 입니다.
# 자세한 정보는 아래 링크에서 확인하실 수 있습니다.
# http://www.snuh.org/health/nMedInfo/nView.do?category=DIS&medid=AA000365
# https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31737
# ===================================================================
# 2순위 질환은 급성 경막하 출혈입니다.
# 급성 경막하 출혈의 증상은 ['두통', '구토', '반신마비', '호흡곤란', '구역', '혼수'] 입니다.
# 증상 일치도는 28.57% 입니다.
# 자세한 정보는 아래 링크에서 확인하실 수 있습니다.
# http://www.snuh.org/health/nMedInfo/nView.do?category=DIS&medid=AA000137
# https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31892
# ===================================================================
# 3순위 질환은 인플루엔자입니다.
# 인플루엔자의 증상은 ['근육통', '두통', '구토', '기침', '설사', '목의통증', '오한', '열'] 입니다.
# 증상 일치도는 22.22% 입니다.
# 자세한 정보는 아래 링크에서 확인하실 수 있습니다.
# http://www.snuh.org/health/nMedInfo/nView.do?category=DIS&medid=AA000009
# https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31620
# ===================================================================

# %%
desc_input = input("이 질환 중 생활 가이드, 주의사항 등을 알고 싶은 질환명을 입력하세요: ")

if desc_input not in sorted_results[:3]:
    print("해당 질환은 입력하신 증상과 일치할 확률이 낮습니다.")
    print("")

cols = ['생활가이드', '주의사항', '예방방법', 'FAQ']
for col in cols:

    if df[df['질환명'] == desc_input][col].values[0] != ".":
        print(f"========={col}=========")
        print(f"{df[df['질환명'] == desc_input][col].values[0]}")
        
    print("")
    if "병원" in df[df['질환명'] == desc_input][col].values[0] or \
        "내원" in df[df['질환명'] == desc_input][col].values[0] or \
        "응급실" in df[df['질환명'] == desc_input][col].values[0]:
        print("****안내****")
        print(f"{desc_input}은 내원이 요구되는 질환입니다. 빠른 시일 내 병원을 방문해주세요.")
# Out:
# 해당 질환은 입력하신 증상과 일치할 확률이 낮습니다.
#
# =========생활가이드=========
# 고도가 올라감에 따라 나타날 수 있는 신체 변화를 이해하고 적절히 대처할 수 있어야 합니다.
#
# =========주의사항=========
# ① 산행 시 짐을 가볍게 하고 음주와 흡연을 하지 않습니다.
# ② 산에 오를 때는 천천히 걸으면서 고도에 적응할 수 있는 시간을 확보합니다.
# ③ 탈수가 잘 발생하므로 수분을 충분히 섭취합니다. 고도가 높아질수록 더 많이 섭취합니다.
# ④ 산을 무리해서 올라가다가 증상을 느껴도 일행이 있으면 참고 넘어가기 쉽습니다. 본인은 저산소증으로 인해 판단이 흐려질 수 있으므로 주위 사람들이 잘 관찰해야 합니다.
#
# =========예방방법=========
# - 등산 초반에 무리해서 올라가지 말고, 적응기간을 갖습니다.
# - 등산 1일 전부터 등산 2일째까지 아세타졸마이드(Acetazoleamide) 5mg/kg을 하루 2번 또는 3번에 나눠서 복용합니다.
# - 고산병 증상이 느껴지는 초기에 등산을 멈추거나 낮은 지대로 내려가는 것이 좋습니다.
# - 또한, 하루에 최대 300m 정도 올라가는 것이 좋다.
