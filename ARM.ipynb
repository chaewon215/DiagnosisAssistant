# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('./crowling/merged_crowling_ver_2.csv', encoding='utf-8')
df.head(3)
# Out:
#           질환명                                                동의어  \
# 0  과민성 대장 증후군  ['과민성대장', '과민성대장증후군', '과민성장증후군', '과민성창자', '과민성...
# 1         당뇨병                                             ['당뇨']
# 2         심부전           ['울혈성심부전', '울혈성심부전증', '울혈심부전', '울혈심부전증']
#
#                                               증상 키워드  \
# 0  ['복통', '두통', '변비', '위경련', '배속가스', '점액변', '체중감소...
# 1  ['변비', '시야장애', '무감각증', '소양감', '거품뇨', '단백뇨', '다...
# 2  ['두통', '불면증', '기침', '야뇨증', '부종', '피로', '심부전', ...
#
#                                             증상 등장 빈도  \
# 0  [{'두통': 1, '복통': 2, '위경련': 1, '배속가스': 1, '변비':...
# 1  [{'무감각증': 1, '소양감': 2, '변비': 1, '저혈압': 1, '거품뇨...
# 2  [{'기침': 1, '피로': 1, '호흡곤란': 2, '부종': 1, '빈맥': ...
#
#                                                  증상1  \
# 0  전형적인 증상으로는 복통과 배변 습관의 변화를 들 수 있는데 복통이 심하더라도 배변...
# 1  약한 고혈당에서는 대부분의 환자들이 증상을 느끼지 못하거나 모호해서 당뇨병이라고 생...
# 2  가장 흔하고 중요한 증상은 숨이 차는 것(호흡곤란)이다. 계단을 오르기만 해도 과도...
#
#                                                  증상2  \
# 0  대장은 정상적으로 하루 1회 정도 배변을 유도하도록 움직입니다. 그러나 대장이 과민...
# 1  당뇨병에 걸리면 소변으로 포도당이 빠져나가는데, 이때 수분을 같이 끌고 나가기 때문...
# 2  울혈성 심부전의 일반적인 증상으로는 전반적으로 몸이 약해짐, 피곤함, 운동을 조금만...
#
#                                                  치료1  \
# 0  치료는 과민성 대장 증후군의 원인이 되는 심리적 불안과 갈등을 제거하는 것이 가장 ...
# 1  제1형 당뇨병의 경우에는 인슐린 치료가 필요하다. 제2형 당뇨병의 경우에는 생활 습...
# 2  급성이냐 만성이냐에 따라 치료 방침은 다르다. 급성 심부전은 주로 1주일 이내 갑자...
#
#                                                  치료2  \
# 0  자극성 장 증후군의 원인이 되는 심리적 불안과 갈등을 제거하는 것이 가장 중요합니다...
# 1  당뇨병의 치료 방법으로는 식사 요법, 운동 요법, 약물 치료가 있습니다. 가벼운 당...
# 2  1. 약물 요법\n  1) 일반적인 원칙\n약물 요법은 이뇨제, 안지오텐신 계열 차...
#
#                                                  경과1  \
# 0  이 질환은 암이나 환자의 인격 이상과도 무관하며 감별을 요하는 다른 질환(궤양성 대...
# 1  갑자기 몸 안에서 인슐린이 부족하게 되면 급성 합병증이 생길 수 있다. 급성 합병증...
# 2  심부전의 이환율과 유병율은 계속 증가하고 있는데, 이는 인구가 노령화되고 의학적 지...
#
#                                                  경과2  \
# 0  암이나 환자의 정신과적인 이상 소견(인격 이상 등)과 관련이 있습니다. 감별이 필요...
# 1  당뇨병의 합병증에는 급성 대사성 합병증과 만성 합병증이 있습니다. 급성 대사성 합병...
# 2  울혈성 심부전은 여성보다 남성에게 더 흔하게 나타납니다. 사망률은 심부전의 발생 원...
#
#                                                생활가이드  \
# 0  과민성 대장 증후군 환자는 스트레스를 줄이는 것이 급선무입니다. 먼저 자신의 주요 ...
# 1  자신이 느끼는 증상만으로 혈당을 조절하는 것은 위험하며, 반드시 자가 혈당 측정기를...
# 2  규칙적 운동이 필요하지만 지나치게 격렬한 운동은 제한하는 것이 좋습니다. 술과 담배...
#
#                                                 주의사항  \
# 0  저지방식, 저자극식을 원칙으로 식사합니다. 지방성 음식, 향신료가 많이 들어간 음식...
# 1  당뇨병을 예방하기 위해서는 일단 당뇨병을 유발할 수 있는 환경 인자인 비만, 좌식 ...
# 2  디지탈리스의 혈중 치료 농도는 일반적으로 1~2mcg/mL입니다. 일반적으로 2mc...
#
#                                                 예방방법 FAQ  \
# 0  생활습관 교정을 통해서 체중을 5~7% 줄이게 되면 일부는 제2형 당뇨병의 발병을 ...   .
# 1  생활습관 교정을 통해서 체중을 5~7% 줄이게 되면 일부는 제2형 당뇨병의 발병을 ...   .
# 2  과도한 음주, 과도한 스트레스, 지속적인 빠른 맥박수는 이 자체가 심부전을 초래할 ...   .
#
#                                                 URL1  \
# 0  http://www.snuh.org/health/nMedInfo/nView.do?c...
# 1  http://www.snuh.org/health/nMedInfo/nView.do?c...
# 2  http://www.snuh.org/health/nMedInfo/nView.do?c...
#
#                                                 URL2
# 0  https://www.amc.seoul.kr/asan/healthinfo/disea...
# 1  https://www.amc.seoul.kr/asan/healthinfo/disea...
# 2  https://www.amc.seoul.kr/asan/healthinfo/disea...

# %%
for i in range(len(df)):
    df.at[i, '증상 키워드'] = df['증상 키워드'][i].replace("[", "").replace("]", "").replace(" ", "").replace("'", "").split(',')

symptoms = list(df["증상 키워드"])
symptoms[:3]
# Out:
# [['복통', '두통', '변비', '위경련', '배속가스', '점액변', '체중감소', '설사'],
#  ['변비',
#   '시야장애',
#   '무감각증',
#   '소양감',
#   '거품뇨',
#   '단백뇨',
#   '다음',
#   '체중감소',
#   '피로감',
#   '고혈당',
#   '저림',
#   '다뇨',
#   '저혈압',
#   '다식'],
#  ['두통',
#   '불면증',
#   '기침',
#   '야뇨증',
#   '부종',
#   '피로',
#   '심부전',
#   '울혈성심부전',
#   '호흡곤란',
#   '소변량감소',
#   '청색증',
#   '빈맥']]

# %%
trns_en = TransactionEncoder()
symptoms_te = trns_en.fit(symptoms).transform(symptoms)

trns_df = pd.DataFrame(symptoms_te, columns=trns_en.columns_)
trns_df
# Out:
#        가래   가슴답답   가슴통증    거품뇨     경련    고혈당     구역     구토   귀의통증   근력약화  ...  \
# 0   False  False  False  False  False  False  False  False  False  False  ...
# 1   False  False  False   True  False   True  False  False  False  False  ...
# 2   False  False  False  False  False  False  False  False  False  False  ...
# 3    True   True  False  False  False  False  False  False  False  False  ...
# 4   False  False  False  False  False  False   True   True  False  False  ...
# 5   False  False  False  False  False  False  False  False  False  False  ...
# 6   False  False  False  False  False  False   True   True  False  False  ...
# 7   False  False  False  False  False  False  False   True  False  False  ...
# 8   False  False  False  False  False  False  False  False  False  False  ...
# 9   False  False  False  False  False  False   True   True  False  False  ...
# 10  False  False   True  False  False  False   True   True  False  False  ...
# 11  False  False  False  False  False  False  False  False  False   True  ...
# 12  False  False  False  False  False  False   True   True  False  False  ...
# 13  False  False  False  False  False  False  False  False  False  False  ...
# 14  False  False  False  False  False  False  False  False  False  False  ...
# 15  False  False  False  False  False  False  False  False   True  False  ...
# 16  False  False  False  False  False  False  False  False  False  False  ...
# 17  False  False  False   True  False  False  False   True  False  False  ...
# 18  False  False  False  False   True  False  False  False  False  False  ...
# 19  False  False  False  False  False  False   True   True  False  False  ...
#
#        혈뇨     혈변   호흡곤란     혼수     홍반  환부의분비물   환부통증   후각소실   후각장애  히스테리구
# 0   False  False  False  False  False   False  False  False  False  False
# 1   False  False  False  False  False   False  False  False  False  False
# 2   False  False   True  False  False   False  False  False  False  False
# 3   False  False   True  False  False   False  False  False  False  False
# 4   False   True  False  False  False   False  False  False  False  False
# 5   False  False  False  False  False   False  False  False  False  False
# 6   False  False   True   True  False   False  False  False  False  False
# 7   False  False  False  False  False   False  False  False  False  False
# 8   False  False  False  False  False   False  False  False  False  False
# 9   False  False   True   True  False   False  False  False  False  False
# 10  False  False   True  False  False   False  False  False  False   True
# 11  False  False   True  False  False   False  False  False  False  False
# 12  False  False  False  False  False   False  False  False  False  False
# 13  False  False  False  False  False    True  False  False  False  False
# 14  False  False  False  False   True   False   True  False  False  False
# 15  False  False  False  False  False   False  False  False  False  False
# 16  False  False  False  False  False   False  False   True   True   True
# 17   True  False  False  False  False   False  False  False  False  False
# 18  False  False  False   True  False   False  False  False  False  False
# 19  False  False  False  False  False   False  False  False  False  False
#
# [20 rows x 118 columns]

# %%
symptoms_sets = apriori(trns_df, min_support=0.1, use_colnames=True, max_len=15)
symptoms_sets.sort_values(['support'], ascending=False)
# Out:
#      support                         itemsets
# 6       0.45                             (두통)
# 2       0.40                             (구토)
# 5       0.35                             (기침)
# 36      0.30                           (호흡곤란)
# 1       0.30                             (구역)
# ..       ...                              ...
# 134     0.10                      (청색증, 호흡곤란)
# 135     0.10                        (혼수, 청색증)
# 136     0.10                        (코막힘, 콧물)
# 137     0.10                       (혼수, 호흡곤란)
# 310     0.10  (재채기, 기침, 비루, 콧물, 인두통및인후통, 코막힘)
#
# [311 rows x 2 columns]

# %%
rules = association_rules(symptoms_sets, metric="confidence", min_threshold=0.5)
# rules.to_csv('./crowling/rules.csv', index=False)
rules.sort_values(['confidence'], ascending=False)
# Out:
#              antecedents     consequents  antecedent support  \
# 0                   (구역)            (구토)                 0.3
# 1163        (변비, 설사, 복통)           (위경련)                 0.1
# 1177  (코막힘, 인두통및인후통, 비루)           (재채기)                 0.1
# 1176               (위경련)    (변비, 설사, 복통)                 0.1
# 1172           (복통, 위경련)        (변비, 설사)                 0.1
# ...                  ...             ...                 ...
# 258                 (빈맥)        (구토, 복통)                 0.2
# 259                 (복통)        (빈맥, 구토)                 0.2
# 1370            (기침, 두통)  (근육통, 열, 목의통증)                 0.2
# 263                 (설사)        (구토, 복통)                 0.2
# 170                 (구역)      (구토, 호흡곤란)                 0.3
#
#       consequent support  support  confidence       lift  leverage  \
# 0                   0.40     0.30         1.0   2.500000     0.180
# 1163                0.10     0.10         1.0  10.000000     0.090
# 1177                0.10     0.10         1.0  10.000000     0.090
# 1176                0.10     0.10         1.0  10.000000     0.090
# 1172                0.10     0.10         1.0  10.000000     0.090
# ...                  ...      ...         ...        ...       ...
# 258                 0.15     0.10         0.5   3.333333     0.070
# 259                 0.15     0.10         0.5   3.333333     0.070
# 1370                0.10     0.10         0.5   5.000000     0.080
# 263                 0.15     0.10         0.5   3.333333     0.070
# 170                 0.15     0.15         0.5   3.333333     0.105
#
#       conviction  zhangs_metric
# 0            inf       0.857143
# 1163         inf       1.000000
# 1177         inf       1.000000
# 1176         inf       1.000000
# 1172         inf       1.000000
# ...          ...            ...
# 258          1.7       0.875000
# 259          1.7       0.875000
# 1370         1.8       1.000000
# 263          1.7       0.875000
# 170          1.7       1.000000
#
# [1810 rows x 10 columns]

# %% [markdown]
# ---

# %%
user_symptoms = input("증상을 입력하세요: ").replace(" ", "").split(",")
user_symptoms
# Out:
# ['두통', '어지럼증', '호흡곤란']

# %%
import itertools

all_subsets = []
for i in range(len(user_symptoms)):
    all_subsets.extend(list(list(itertools.combinations(user_symptoms, i+1))))
all_subsets
# Out:
# [('두통',),
#  ('어지럼증',),
#  ('호흡곤란',),
#  ('두통', '어지럼증'),
#  ('두통', '호흡곤란'),
#  ('어지럼증', '호흡곤란'),
#  ('두통', '어지럼증', '호흡곤란')]

# %%
keyword_combi = pd.DataFrame(columns=["keyword", "support"])

for i in range(len(symptoms_sets)):
    for subset in all_subsets:
        if set(subset) == (set(symptoms_sets['itemsets'][i])):
            keyword_combi.loc[len(keyword_combi)] = \
                [list(symptoms_sets['itemsets'][i]), symptoms_sets['support'][i]]
keyword_combi.sort_values(['support'], ascending=False)
# Out:
#         keyword  support
# 0          [두통]     0.45
# 2        [호흡곤란]     0.30
# 1        [어지럼증]     0.15
# 3    [두통, 호흡곤란]     0.15
# 4  [호흡곤란, 어지럼증]     0.10

# %%
user_syt_df = pd.DataFrame(columns=rules.columns)
for i in range(len(keyword_combi)):        
    filtered = rules[rules["antecedents"] == frozenset(keyword_combi["keyword"][i])]
    filtered.sort_values(['support'], ascending=False)
    user_syt_df = pd.concat([user_syt_df, filtered])
user_syt_df.sort_values(['confidence'], ascending=False)
# Out:
# C:\Users\chaewon\AppData\Local\Temp\ipykernel_3460\2032524936.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   user_syt_df = pd.concat([user_syt_df, filtered])
#        antecedents         consequents  antecedent support  \
# 1265  (어지럼증, 호흡곤란)        (기침, 구역, 구토)                0.10
# 782   (어지럼증, 호흡곤란)            (기침, 구토)                0.10
# 712   (호흡곤란, 어지럼증)            (기침, 구역)                0.10
# 691   (호흡곤란, 어지럼증)            (구역, 구토)                0.10
# 413   (어지럼증, 호흡곤란)                (기침)                0.10
# 279   (어지럼증, 호흡곤란)                (구토)                0.10
# 211   (호흡곤란, 어지럼증)                (구역)                0.10
# 626     (두통, 호흡곤란)            (구역, 구토)                0.15
# 250     (두통, 호흡곤란)                (구토)                0.15
# 368     (두통, 호흡곤란)                (기침)                0.15
# 471     (두통, 호흡곤란)               (청색증)                0.15
# 476     (두통, 호흡곤란)                (혼수)                0.15
# 994     (두통, 호흡곤란)           (기침, 청색증)                0.15
# 723     (두통, 호흡곤란)            (혼수, 구역)                0.15
# 804     (두통, 호흡곤란)            (혼수, 구토)                0.15
# 19          (어지럼증)                (구토)                0.15
# 1293    (두통, 호흡곤란)        (혼수, 구역, 구토)                0.15
# 184     (두통, 호흡곤란)                (구역)                0.15
# 7           (어지럼증)                (구역)                0.15
# 414         (어지럼증)          (기침, 호흡곤란)                0.15
# 156         (어지럼증)            (구역, 구토)                0.15
# 42          (어지럼증)                (기침)                0.15
# 116         (어지럼증)              (호흡곤란)                0.15
# 1271        (어지럼증)  (구토, 기침, 구역, 호흡곤란)                0.15
# 783         (어지럼증)      (기침, 구토, 호흡곤란)                0.15
# 713         (어지럼증)      (기침, 구역, 호흡곤란)                0.15
# 692         (어지럼증)      (구역, 구토, 호흡곤란)                0.15
# 609         (어지럼증)        (구역, 기침, 구토)                0.15
# 49          (호흡곤란)                (기침)                0.30
# 281         (어지럼증)          (구토, 호흡곤란)                0.15
# 237         (어지럼증)            (기침, 구토)                0.15
# 212         (어지럼증)          (구역, 호흡곤란)                0.15
# 178         (어지럼증)            (기침, 구역)                0.15
# 171         (호흡곤란)            (구역, 구토)                0.30
# 12          (호흡곤란)                (구역)                0.30
# 25          (호흡곤란)                (구토)                0.30
# 57          (호흡곤란)                (두통)                0.30
#
#       consequent support  support  confidence       lift  leverage  \
# 1265                0.10     0.10    1.000000  10.000000    0.0900
# 782                 0.15     0.10    1.000000   6.666667    0.0850
# 712                 0.10     0.10    1.000000  10.000000    0.0900
# 691                 0.30     0.10    1.000000   3.333333    0.0700
# 413                 0.35     0.10    1.000000   2.857143    0.0650
# 279                 0.40     0.10    1.000000   2.500000    0.0600
# 211                 0.30     0.10    1.000000   3.333333    0.0700
# 626                 0.30     0.10    0.666667   2.222222    0.0550
# 250                 0.40     0.10    0.666667   1.666667    0.0400
# 368                 0.35     0.10    0.666667   1.904762    0.0475
# 471                 0.15     0.10    0.666667   4.444444    0.0775
# 476                 0.15     0.10    0.666667   4.444444    0.0775
# 994                 0.10     0.10    0.666667   6.666667    0.0850
# 723                 0.10     0.10    0.666667   6.666667    0.0850
# 804                 0.10     0.10    0.666667   6.666667    0.0850
# 19                  0.40     0.10    0.666667   1.666667    0.0400
# 1293                0.10     0.10    0.666667   6.666667    0.0850
# 184                 0.30     0.10    0.666667   2.222222    0.0550
# 7                   0.30     0.10    0.666667   2.222222    0.0550
# 414                 0.20     0.10    0.666667   3.333333    0.0700
# 156                 0.30     0.10    0.666667   2.222222    0.0550
# 42                  0.35     0.10    0.666667   1.904762    0.0475
# 116                 0.30     0.10    0.666667   2.222222    0.0550
# 1271                0.10     0.10    0.666667   6.666667    0.0850
# 783                 0.10     0.10    0.666667   6.666667    0.0850
# 713                 0.10     0.10    0.666667   6.666667    0.0850
# 692                 0.15     0.10    0.666667   4.444444    0.0775
# 609                 0.10     0.10    0.666667   6.666667    0.0850
# 49                  0.35     0.20    0.666667   1.904762    0.0950
# 281                 0.15     0.10    0.666667   4.444444    0.0775
# 237                 0.15     0.10    0.666667   4.444444    0.0775
# 212                 0.15     0.10    0.666667   4.444444    0.0775
# 178                 0.10     0.10    0.666667   6.666667    0.0850
# 171                 0.30     0.15    0.500000   1.666667    0.0600
# 12                  0.30     0.15    0.500000   1.666667    0.0600
# 25                  0.40     0.15    0.500000   1.250000    0.0300
# 57                  0.45     0.15    0.500000   1.111111    0.0150
#
#       conviction  zhangs_metric
# 1265         inf       1.000000
# 782          inf       0.944444
# 712          inf       1.000000
# 691          inf       0.777778
# 413          inf       0.722222
# 279          inf       0.666667
# 211          inf       0.777778
# 626         2.10       0.647059
# 250         1.80       0.470588
# 368         1.95       0.558824
# 471         2.55       0.911765
# 476         2.55       0.911765
# 994         2.70       1.000000
# 723         2.70       1.000000
# 804         2.70       1.000000
# 19          1.80       0.470588
# 1293        2.70       1.000000
# 184         2.10       0.647059
# 7           2.10       0.647059
# 414         2.40       0.823529
# 156         2.10       0.647059
# 42          1.95       0.558824
# 116         2.10       0.647059
# 1271        2.70       1.000000
# 783         2.70       1.000000
# 713         2.70       1.000000
# 692         2.55       0.911765
# 609         2.70       1.000000
# 49          1.95       0.678571
# 281         2.55       0.911765
# 237         2.55       0.911765
# 212         2.55       0.911765
# 178         2.70       1.000000
# 171         1.40       0.571429
# 12          1.40       0.571429
# 25          1.20       0.285714
# 57          1.10       0.142857

# %%
item_sets = []
for i in range(len(user_syt_df)):
    item_sets.append(list(user_syt_df['antecedents'].values[i]) + list(user_syt_df['consequents'].values[i]))
item_sets
# Out:
# [['어지럼증', '구역'],
#  ['어지럼증', '구토'],
#  ['어지럼증', '기침'],
#  ['어지럼증', '호흡곤란'],
#  ['어지럼증', '구역', '구토'],
#  ['어지럼증', '기침', '구역'],
#  ['어지럼증', '구역', '호흡곤란'],
#  ['어지럼증', '기침', '구토'],
#  ['어지럼증', '구토', '호흡곤란'],
#  ['어지럼증', '기침', '호흡곤란'],
#  ['어지럼증', '구역', '기침', '구토'],
#  ['어지럼증', '구역', '구토', '호흡곤란'],
#  ['어지럼증', '기침', '구역', '호흡곤란'],
#  ['어지럼증', '기침', '구토', '호흡곤란'],
#  ['어지럼증', '구토', '기침', '구역', '호흡곤란'],
#  ['호흡곤란', '구역'],
#  ['호흡곤란', '구토'],
#  ['호흡곤란', '기침'],
#  ['호흡곤란', '두통'],
#  ['호흡곤란', '구역', '구토'],
#  ['두통', '호흡곤란', '구역'],
#  ['두통', '호흡곤란', '구토'],
#  ['두통', '호흡곤란', '기침'],
#  ['두통', '호흡곤란', '청색증'],
#  ['두통', '호흡곤란', '혼수'],
#  ['두통', '호흡곤란', '구역', '구토'],
#  ['두통', '호흡곤란', '혼수', '구역'],
#  ['두통', '호흡곤란', '혼수', '구토'],
#  ['두통', '호흡곤란', '기침', '청색증'],
#  ['두통', '호흡곤란', '혼수', '구역', '구토'],
#  ['호흡곤란', '어지럼증', '구역'],
#  ['어지럼증', '호흡곤란', '구토'],
#  ['어지럼증', '호흡곤란', '기침'],
#  ['호흡곤란', '어지럼증', '구역', '구토'],
#  ['호흡곤란', '어지럼증', '기침', '구역'],
#  ['어지럼증', '호흡곤란', '기침', '구토'],
#  ['어지럼증', '호흡곤란', '기침', '구역', '구토']]

# %%
def match_score(disease):
    score = 0
    for i in range(len(df)):
        if df["질환명"][i] == disease:
            length = len(df["증상 키워드"][i])
            for symptom in user_symptoms:
                if symptom in df["증상 키워드"][i]:
                    score += 1
                else:
                    length += 1
    
    score = (score / length) * 100
    
    return score

# %%
best_matches = {}
able_diseases = {}
able_df_disases = {}

for i in range(len(df["증상 키워드"])):
    if set(user_symptoms) == set(df["증상 키워드"][i]):
        best_matches[df["질환명"][i]] = match_score(df["질환명"][i])
    else:
        if len(item_sets) != 0:        
            for item_set in item_sets:
                if set(item_set).issubset(set(df["증상 키워드"][i])):
                    able_diseases[df["질환명"][i]] = match_score(df["질환명"][i])
        else:
            if set(user_symptoms).issubset(set(df["증상 키워드"][i])):
                able_df_disases[df["질환명"][i]] = match_score(df["질환명"][i])

# %%
results = {}

if len(best_matches) != 0:
    scores = sorted(list(best_matches.values()), reverse=True)
    for score in scores:
        best = list(best_matches.keys())[list(best_matches.values()).index(score)]
        print(f"입력하신 증상에 대해 가장 적합한 질환은 {best}이며, 일치도는 {score:.2f}% 입니다.")
        results[best] = score
        
if len(able_diseases) != 0:
    scores = sorted(list(able_diseases.values()), reverse=True)
    for score in scores:
        able = list(able_diseases.keys())[list(able_diseases.values()).index(score)]
        print(f"ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 {able}이며, 일치도는 {score:.2f}% 입니다.")
        results[able] = score
        
if len(able_df_disases) != 0:
    scores = sorted(list(able_df_disases.values()), reverse=True)
    for score in scores:
        able_df = list(able_df_disases.keys())[list(able_df_disases.values()).index(score)]
        print(f"Dataframe 내 탐색 기반 입력하신 증상에 대해 가능성 있는 질환은 {able_df}, 일치도는 {score:.2f}% 입니다.")
        results[able_df] = score
# Out:
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 급성 경막하 출혈이며, 일치도는 28.57% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 고산병이며, 일치도는 20.00% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 심부전이며, 일치도는 15.38% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 천식이며, 일치도는 12.50% 입니다.
# ARM 기반 입력하신 증상에 대해 가능성 있는 질환은 아나필락시스이며, 일치도는 10.00% 입니다.

# %%
sorted_results = []
if len(results) != 0:
    scores = sorted(list(results.values()), reverse=True)
    for score in scores:
        sorted_results.append(list(results.keys())[list(results.values()).index(score)])
print(sorted_results)
# Out:
# ['급성 경막하 출혈', '고산병', '심부전', '천식', '아나필락시스']

# %%
print("===================================================================")
for i in range(3):
    if i < len(sorted_results):
        print(f"{i+1}순위 질환은 {sorted_results[i]}입니다.")
        print(f"{sorted_results[i]}의 증상은 {df[df['질환명'] == sorted_results[i]]['증상 키워드'].values[0]} 입니다.")
        print(f"증상 일치도는 {results[sorted_results[i]]:.2f}% 입니다.")
        print(f"자세한 정보는 아래 링크에서 확인하실 수 있습니다.")
        print(df[df['질환명'] == sorted_results[i]]['URL1'].values[0])
        print(df[df['질환명'] == sorted_results[i]]['URL2'].values[0])
        print("===================================================================")
    else:
        break
# Out:
# ===================================================================
# 1순위 질환은 급성 경막하 출혈입니다.
# 급성 경막하 출혈의 증상은 ['구토', '두통', '반신마비', '구역', '혼수', '호흡곤란'] 입니다.
# 증상 일치도는 28.57% 입니다.
# 자세한 정보는 아래 링크에서 확인하실 수 있습니다.
# http://www.snuh.org/health/nMedInfo/nView.do?category=DIS&medid=AA000137
# https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=31892
# ===================================================================
# 2순위 질환은 고산병입니다.
# 고산병의 증상은 ['구토', '두통', '말초부종', '기침', '수면장애', '의식변화', '구역', '탈수', '의식장애', '혼수', '호흡곤란', '식욕부진', '청색증', '어지럼증', '마비'] 입니다.
# 증상 일치도는 20.00% 입니다.
# 자세한 정보는 아래 링크에서 확인하실 수 있습니다.
# http://www.snuh.org/health/nMedInfo/nView.do?category=DIS&medid=AA000723
# https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=32327
# ===================================================================
# 3순위 질환은 심부전입니다.
# 심부전의 증상은 ['두통', '불면증', '기침', '야뇨증', '부종', '피로', '심부전', '울혈성심부전', '호흡곤란', '소변량감소', '청색증', '빈맥'] 입니다.
# 증상 일치도는 15.38% 입니다.
# 자세한 정보는 아래 링크에서 확인하실 수 있습니다.
# http://www.snuh.org/health/nMedInfo/nView.do?category=DIS&medid=AA000337
# https://www.amc.seoul.kr/asan/healthinfo/disease/diseaseDetail.do?contentId=30314
# ===================================================================

# %%
desc_input = input("이 질환 중 생활 가이드, 주의사항 등을 알고 싶은 질환명을 입력하세요: ")

if desc_input not in sorted_results[:3]:
    print("해당 질환은 입력하신 증상과 일치할 확률이 낮습니다.")
    print("")

cols = ['생활가이드', '주의사항', '예방방법', 'FAQ']
for col in cols:

    if df[df['질환명'] == desc_input][col].values[0] != ".":
        print(f"========={col}=========")
        print(f"{df[df['질환명'] == desc_input][col].values[0]}")
        
    print("")
    if "병원" in df[df['질환명'] == desc_input][col].values[0] or "내원" in df[df['질환명'] == desc_input][col].values[0]:
        print("****안내****")
        print(f"{desc_input}은 내원이 요구되는 질환입니다. 빠른 시일 내 병원을 방문해주세요.")
# Out:
# 해당 질환은 입력하신 증상과 일치할 확률이 낮습니다.
#
# =========생활가이드=========
# 패혈증 발병 후 짧은 시간 내에 사망할 수 있으므로, 집에서 혼자 치료할 수 없으며 증상이 나타나면 신속히 병원에 가서 치료를 받아야 합니다.
#
# ****안내****
# 패혈증은 내원이 요구되는 질환입니다. 빠른 시일 내 병원을 방문해주세요.
